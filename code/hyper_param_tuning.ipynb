# %% [markdown]
# ### Bayesian Optimization을 이용하여 application과 previous로 만들어진 집합의 하이퍼 파라미터 튜닝

# %% [markdown]
# #### 라이브러리 및 데이터 세트 로딩. 이전 application 데이터의 FE 함수 복사

# %%
import numpy as np
import pandas as pd
import gc
import time
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 200)

# %% [markdown]
# ##### 코랩 버전은 Google Drive에서 데이터 세트를 로딩

# %%
import os, sys 
from google.colab import drive 

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
def get_dataset():
    default_dir = "/content/gdrive/MyDrive/ML/kaggle/home-credit-default-risk/data"
    app_train = pd.read_csv(os.path.join(default_dir, 'application_train.csv'))
    app_test = pd.read_csv(os.path.join(default_dir, 'application_test.csv'))
    apps = pd.concat([app_train, app_test])
    prev = pd.read_csv(os.path.join(default_dir, 'previous_application.csv'))

    return apps, prev

apps, prev = get_dataset()

# %% [markdown]
# #### 이전 application 데이터의 feature engineering 함수 복사

# %%
def get_apps_processed(apps):
    
    # EXT_SOURCE_X FEATURE 가공
    apps['APPS_EXT_SOURCE_MEAN'] = apps[['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3']].mean(axis=1)
    apps['APPS_EXT_SOURCE_STD'] = apps[['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3']].std(axis=1)
    apps['APPS_EXT_SOURCE_STD'] = apps['APPS_EXT_SOURCE_STD'].fillna(apps['APPS_EXT_SOURCE_STD'].mean())
    
    # AMT_CREDIT 비율로 Feature 가공
    apps['APPS_ANNUITY_CREDIT_RATIO'] = apps['AMT_ANNUITY']/apps['AMT_CREDIT']
    apps['APPS_GOODS_CREDIT_RATIO'] = apps['AMT_GOODS_PRICE']/apps['AMT_CREDIT']
    
    # AMT_INCOME_TOTAL 비율로 Feature 가공
    apps['APPS_ANNUITY_INCOME_RATIO'] = apps['AMT_ANNUITY']/apps['AMT_INCOME_TOTAL']
    apps['APPS_CREDIT_INCOME_RATIO'] = apps['AMT_CREDIT']/apps['AMT_INCOME_TOTAL']
    apps['APPS_GOODS_INCOME_RATIO'] = apps['AMT_GOODS_PRICE']/apps['AMT_INCOME_TOTAL']
    apps['APPS_CNT_FAM_INCOME_RATIO'] = apps['AMT_INCOME_TOTAL']/apps['CNT_FAM_MEMBERS']
    
    # DAYS_BIRTH, DAYS_EMPLOYED 비율로 Feature 가공
    apps['APPS_EMPLOYED_BIRTH_RATIO'] = apps['DAYS_EMPLOYED']/apps['DAYS_BIRTH']
    apps['APPS_INCOME_EMPLOYED_RATIO'] = apps['AMT_INCOME_TOTAL']/apps['DAYS_EMPLOYED']
    apps['APPS_INCOME_BIRTH_RATIO'] = apps['AMT_INCOME_TOTAL']/apps['DAYS_BIRTH']
    apps['APPS_CAR_BIRTH_RATIO'] = apps['OWN_CAR_AGE'] / apps['DAYS_BIRTH']
    apps['APPS_CAR_EMPLOYED_RATIO'] = apps['OWN_CAR_AGE'] / apps['DAYS_EMPLOYED']
    
    return apps

# %% [markdown]
# #### previous 데이터 가공후 인코딩 및 최종 데이터 집합 생성하는 함수 선언

# %%
from sklearn.model_selection import train_test_split
from lightgbm import LGBMClassifier

# 신청금액과 실제 대출액, 상품금액과의 차이 비율, 만기일 차이 비교, 이자율 계산등의 주요 컬럼 가공 생산. 
def get_prev_processed(prev):
    # 대출 신청 금액과 실제 대출액/대출 상품금액 차이 및 비율
    prev['PREV_CREDIT_DIFF'] = prev['AMT_APPLICATION'] - prev['AMT_CREDIT']
    prev['PREV_GOODS_DIFF'] = prev['AMT_APPLICATION'] - prev['AMT_GOODS_PRICE']
    prev['PREV_CREDIT_APPL_RATIO'] = prev['AMT_CREDIT']/prev['AMT_APPLICATION']
    # prev['PREV_ANNUITY_APPL_RATIO'] = prev['AMT_ANNUITY']/prev['AMT_APPLICATION']
    prev['PREV_GOODS_APPL_RATIO'] = prev['AMT_GOODS_PRICE']/prev['AMT_APPLICATION']
    
    prev['DAYS_FIRST_DRAWING'].replace(365243, np.nan, inplace= True)
    prev['DAYS_FIRST_DUE'].replace(365243, np.nan, inplace= True)
    prev['DAYS_LAST_DUE_1ST_VERSION'].replace(365243, np.nan, inplace= True)
    prev['DAYS_LAST_DUE'].replace(365243, np.nan, inplace= True)
    prev['DAYS_TERMINATION'].replace(365243, np.nan, inplace= True)
    # 첫번째 만기일과 마지막 만기일까지의 기간
    prev['PREV_DAYS_LAST_DUE_DIFF'] = prev['DAYS_LAST_DUE_1ST_VERSION'] - prev['DAYS_LAST_DUE']
    # 매월 납부 금액과 납부 횟수 곱해서 전체 납부 금액 구함. 
    all_pay = prev['AMT_ANNUITY'] * prev['CNT_PAYMENT']
    # 전체 납부 금액 대비 AMT_CREDIT 비율을 구하고 여기에 다시 납부횟수로 나누어서 이자율 계산. 
    prev['PREV_INTERESTS_RATE'] = (all_pay/prev['AMT_CREDIT'] - 1)/prev['CNT_PAYMENT']
        
    return prev

# 기존 컬럼및 위에서 가공된 신규 컬럼들에 대해서 SK_ID_CURR 레벨로 Aggregation 수행.  
def get_prev_amt_agg(prev):

    agg_dict = {
         # 기존 주요 컬럼들을 SK_ID_CURR 레벨로 Aggregation 수행. . 
        'SK_ID_CURR':['count'],
        'AMT_CREDIT':['mean', 'max', 'sum'],
        'AMT_ANNUITY':['mean', 'max', 'sum'], 
        'AMT_APPLICATION':['mean', 'max', 'sum'],
        'AMT_DOWN_PAYMENT':['mean', 'max', 'sum'],
        'AMT_GOODS_PRICE':['mean', 'max', 'sum'],
        'RATE_DOWN_PAYMENT': ['min', 'max', 'mean'],
        'DAYS_DECISION': ['min', 'max', 'mean'],
        'CNT_PAYMENT': ['mean', 'sum'],
        # 신규 가공 컬럼들을 SK_ID_CURR 레벨로 Aggregation 수행. .
        'PREV_CREDIT_DIFF':['mean', 'max', 'sum'], 
        'PREV_CREDIT_APPL_RATIO':['mean', 'max'],
        'PREV_GOODS_DIFF':['mean', 'max', 'sum'],
        'PREV_GOODS_APPL_RATIO':['mean', 'max'],
        'PREV_DAYS_LAST_DUE_DIFF':['mean', 'max', 'sum'],
        'PREV_INTERESTS_RATE':['mean', 'max']
    }

    prev_group = prev.groupby('SK_ID_CURR')
    prev_amt_agg = prev_group.agg(agg_dict)

    # multi index 컬럼을 '_'로 연결하여 컬럼명 변경
    prev_amt_agg.columns = ["PREV_"+ "_".join(x).upper() for x in prev_amt_agg.columns.ravel()]
    
    # 'SK_ID_CURR'로 조인하기 위해 SK_ID_CURR을 컬럼으로 변환  
    prev_amt_agg = prev_amt_agg.reset_index()
    
    return prev_amt_agg

# NAME_CONTRACT_STATUS의 SK_ID_CURR별 Approved, Refused의 건수 계산.  
def get_prev_refused_appr_agg(prev):
    # 원래 groupby 컬럼 + 세부 기준 컬럼으로 groupby 수행. 세분화된 레벨로 aggregation 수행 한 뒤에 unstack()으로 컬럼레벨로 변형. 
    prev_refused_appr_group = prev[prev['NAME_CONTRACT_STATUS'].isin(['Approved', 'Refused'])].groupby([ 'SK_ID_CURR', 'NAME_CONTRACT_STATUS'])
    prev_refused_appr_agg = prev_refused_appr_group['SK_ID_CURR'].count().unstack()
    # 컬럼명 변경. 
    prev_refused_appr_agg.columns = ['PREV_APPROVED_COUNT', 'PREV_REFUSED_COUNT' ]
    # NaN값은 모두 0으로 변경. 
    prev_refused_appr_agg = prev_refused_appr_agg.fillna(0)
    
    # 'SK_ID_CURR'로 조인하기 위해 SK_ID_CURR을 컬럼으로 변환  
    prev_refused_appr_agg = prev_refused_appr_agg.reset_index()
    
    return prev_refused_appr_agg

# NAME_CONTRACT_TYPE의 SK_ID_CURR별 Cash loans의 건수 계산.
def get_prev_cash_loans_agg(prev):
    cond_cash_loans = (prev['NAME_CONTRACT_TYPE'] == 'Cash loans')
    prev_cash_loans = prev[cond_cash_loans]

    prev_cash_loans_agg = prev_cash_loans.groupby('SK_ID_CURR')['SK_ID_CURR'].count()
    prev_cash_loans_agg = prev_cash_loans_agg.reset_index(name="PREV_CASH_LOANS_COUNT")

    return prev_cash_loans_agg
    
# 앞에서 구한 prev_amt_agg와 prev_refused_appr_agg를 조인하고 SK_ID_CURR별 APPROVED_COUNT 및 REFUSED_COUNT 비율 생성
def get_prev_agg(prev):
    prev = get_prev_processed(prev)
    prev_amt_agg = get_prev_amt_agg(prev)
    prev_refused_appr_agg = get_prev_refused_appr_agg(prev)
    
    # prev_amt_agg와 조인. 
    prev_agg = prev_amt_agg.merge(prev_refused_appr_agg, on='SK_ID_CURR', how='left')
    # SK_ID_CURR별 과거 대출건수 대비 APPROVED_COUNT 및 REFUSED_COUNT 비율 생성. 
    prev_agg['PREV_REFUSED_RATIO'] = prev_agg['PREV_REFUSED_COUNT']/prev_agg['PREV_SK_ID_CURR_COUNT']
    prev_agg['PREV_APPROVED_RATIO'] = prev_agg['PREV_APPROVED_COUNT']/prev_agg['PREV_SK_ID_CURR_COUNT']
    # 'PREV_REFUSED_COUNT', 'PREV_APPROVED_COUNT' 컬럼 drop 
    prev_agg = prev_agg.drop(['PREV_REFUSED_COUNT', 'PREV_APPROVED_COUNT'], axis=1)
    
    return prev_agg

# 앞에서 구한 prev_agg와 prev_cash_loans_agg를 조인하고 SK_ID_CURR별 CASH_LOANS_COUNT 비율 생성
def get_prev_agg_with_cash(prev):
    prev_agg = get_prev_agg(prev)
    prev_cash_loans_agg = get_prev_cash_loans_agg(prev)
    
    # prev_agg 조인. 
    prev_agg = prev_agg.merge(prev_cash_loans_agg, on='SK_ID_CURR', how='left')
    
    # 결측치는 0으로 대체한 후(PREV_CASH_LOANS_COUNT 컬럼), 
    # SK_ID_CURR별 과거 대출건수 대비 CASH_LOANS_COUNT 비율 생성. 
    prev_agg = prev_agg.fillna(0, inplace=False)
    prev_agg['PREV_CASH_LOANS_RATIO'] = prev_agg['PREV_CASH_LOANS_COUNT'] / prev_agg['PREV_SK_ID_CURR_COUNT']
    
    # 'PREV_CASH_LOANS_COUNT' 컬럼 drop 
    prev_agg = prev_agg.drop(['PREV_CASH_LOANS_COUNT'], axis=1)
    
    return prev_agg

# apps와 previous 데이터 세트를 SK_ID_CURR레벨로 다양한 컬럼이 aggregation되어 있는 prev_agg 조인
def get_apps_all_with_prev_agg(apps, prev):
    apps_all =  get_apps_processed(apps)
    prev_agg = get_prev_agg_with_cash(prev)
    print('prev_agg shape:', prev_agg.shape)
    print('apps_all before merge shape:', apps_all.shape)
    apps_all = apps_all.merge(prev_agg, on='SK_ID_CURR', how='left')
    print('apps_all after merge with prev_agg shape:', apps_all.shape)
    
    return apps_all

# Label 인코딩 수행. 
def get_apps_all_encoded(apps_all):
    object_columns = apps_all.dtypes[apps_all.dtypes == 'object'].index.tolist()
    for column in object_columns:
        apps_all[column] = pd.factorize(apps_all[column])[0]
    
    return apps_all

# 학습 데이터와 테스트 데이터 세트 분리. 
def get_apps_all_train_test(apps_all):
    apps_all_train = apps_all[~apps_all['TARGET'].isnull()]
    apps_all_test = apps_all[apps_all['TARGET'].isnull()]

    apps_all_test = apps_all_test.drop('TARGET', axis=1)
    
    return apps_all_train, apps_all_test

# 학습 수행. 
def train_apps_all(apps_all_train):
    ftr_app = apps_all_train.drop(['SK_ID_CURR', 'TARGET'], axis=1)
    target_app = apps_all_train['TARGET']

    train_x, valid_x, train_y, valid_y = train_test_split(ftr_app, target_app, test_size=0.3, random_state=2020)
    print('train shape:', train_x.shape, 'valid shape:', valid_x.shape)
    clf = LGBMClassifier(
            n_jobs=-1,
            n_estimators=1000,
            learning_rate=0.02,
            num_leaves=32,
            subsample=0.8,
            max_depth=12,
            silent=-1,
            verbose=-1
                )

    clf.fit(train_x, train_y, eval_set=[(train_x, train_y), (valid_x, valid_y)], eval_metric= 'auc', verbose= 100, 
                early_stopping_rounds= 100)
    
    return clf

# %% [markdown]
# ##### 최종 집합 생성 및 인코딩, 학습/테스트 데이터 분리, 학습/검증 피처와 타겟 데이터 분리

# %%
apps_all = get_apps_all_with_prev_agg(apps, prev)
apps_all = get_apps_all_encoded(apps_all)
apps_all_train, apps_all_test = get_apps_all_train_test(apps_all)
ftr_app = apps_all_train.drop(['SK_ID_CURR', 'TARGET'], axis=1)
target_app = apps_all_train['TARGET']
train_x, valid_x, train_y, valid_y = train_test_split(ftr_app, target_app, test_size=0.3, random_state=2020)
# Out:
# prev_agg shape: (338857, 43)
# apps_all before merge shape: (356255, 135)
# apps_all after merge with prev_agg shape: (356255, 177)

# %% [markdown]
# #### Bayesian Optimization

# %%
# bayesian optimization 패키지 설치
# !pip install bayesian-optimization
# Out:
# Collecting bayesian-optimization
#   Downloading https://files.pythonhosted.org/packages/bb/7a/fd8059a3881d3ab37ac8f72f56b73937a14e8bb14a9733e68cc8b17dbe3c/bayesian-optimization-1.2.0.tar.gz
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from bayesian-optimization) (1.19.5)
# Requirement already satisfied: scipy>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from bayesian-optimization) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.18.0 in /usr/local/lib/python3.7/dist-packages (from bayesian-optimization) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.18.0->bayesian-optimization) (1.0.1)
# Building wheels for collected packages: bayesian-optimization
#   Building wheel for bayesian-optimization (setup.py) ... done
#   Created wheel for bayesian-optimization: filename=bayesian_optimization-1.2.0-cp37-none-any.whl size=11686 sha256=6a5fe8cc44d7a8bd62532f6e705f682d0756b7ade062603f3f81b6497244ca52
#   Stored in directory: /root/.cache/pip/wheels/5a/56/ae/e0e3c1fc1954dc3ec712e2df547235ed072b448094d8f94aec
# Successfully built bayesian-optimization
# Installing collected packages: bayesian-optimization
# Successfully installed bayesian-optimization-1.2.0

# %%
from bayes_opt import BayesianOptimization
from sklearn.metrics import roc_auc_score
from lightgbm import LGBMClassifier

# %% [markdown]
# ##### 함수의 입력값 search 범위(하이퍼 파라미터 별 입력 범위) 를 설정

# %%
bayesian_params = {
    'max_depth' : (6, 16),
    'num_leaves' : (24, 64),
    'min_child_samples' : (10, 200),
    'min_child_weight' : (1, 50),
    'subsample' : (0.5, 1),
    'colsample_bytree' : (0.5, 1),
    'max_bin' : (10, 500),
    'reg_lambda' : (0.0001, 10),
    'reg_alpha' : (0.01, 50)
}

# %% [markdown]
# ##### 최대 값을 구할 함수 선언.
# * iteration 시 마다 hyperparameter를 입력받아 classifier 학습하고 roc_auc_score값을 반환

# %%
def lgb_roc_eval(max_depth, num_leaves, min_child_samples, min_child_weight, subsample,
                 colsample_bytree, max_bin, reg_lambda, reg_alpha):
    params = {
        "n_estimators":500, "learning_rate":0.02,
        'max_depth': int(round(max_depth)),
        'num_leaves': int(round(num_leaves)), 
        'min_child_samples': int(round(min_child_samples)),
        'min_child_weight': int(round(min_child_weight)),
        'subsample': max(min(subsample, 1), 0),
        'colsample_bytree': max(min(colsample_bytree, 1), 0),
        'max_bin':  max(int(round(max_bin)), 10),
        'reg_lambda': max(reg_lambda, 0),
        'reg_alpha': max(reg_alpha, 0)
    }
    
    lgb_model = LGBMClassifier(**params)
    lgb_model.fit(train_x, train_y, eval_set=[(train_x, train_y), (valid_x, valid_y)], eval_metric= 'auc', verbose= 100, 
                  early_stopping_rounds= 100)
    valid_proba = lgb_model.predict_proba(valid_x)[:, 1]
    roc_auc = roc_auc_score(valid_y, valid_proba)

    return roc_auc

# %% [markdown]
# ##### BayesianOptimization 객체 생성 후 함수 반환값이 최대가 되는 입력값 search를 위한 iteration 수행

# %%
lgbBO = BayesianOptimization(f=lgb_roc_eval, pbounds=bayesian_params, random_state=0)
lgbBO.maximize(init_points=5, n_iter=25)
# Out:
# |   iter    |  target   | colsam... |  max_bin  | max_depth | min_ch... | min_ch... | num_le... | reg_alpha | reg_la... | subsample |
# -------------------------------------------------------------------------------------------------------------------------------------
# Training until validation scores don't improve for 100 rounds.
# [100]	training's binary_logloss: 0.246035	training's auc: 0.769621	valid_1's binary_logloss: 0.249109	valid_1's auc: 0.754699
# [200]	training's binary_logloss: 0.238398	training's auc: 0.787558	valid_1's binary_logloss: 0.244258	valid_1's auc: 0.766091
# [300]	training's binary_logloss: 0.233969	training's auc: 0.79913	valid_1's binary_logloss: 0.242411	valid_1's auc: 0.77112
# [400]	training's binary_logloss: 0.230639	training's auc: 0.808015	valid_1's binary_logloss: 0.241523	valid_1's auc: 0.773628
# [500]	training's binary_logloss: 0.227654	training's auc: 0.816116	valid_1's binary_logloss: 0.24091	valid_1's auc: 0.775323
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.227654	training's auc: 0.816116	valid_1's binary_logloss: 0.24091	valid_1's auc: 0.775323
# |  1        |  0.7753   |  0.7744   |  360.4    |  12.03    |  113.5    |  21.76    |  49.84    |  21.88    |  8.918    |  0.9818   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's binary_logloss: 0.247455	training's auc: 0.762739	valid_1's binary_logloss: 0.249121	valid_1's auc: 0.753811
# [200]	training's binary_logloss: 0.240444	training's auc: 0.780368	valid_1's binary_logloss: 0.244197	valid_1's auc: 0.766012
# [300]	training's binary_logloss: 0.236501	training's auc: 0.790937	valid_1's binary_logloss: 0.242315	valid_1's auc: 0.771041
# [400]	training's binary_logloss: 0.233548	training's auc: 0.799007	valid_1's binary_logloss: 0.241318	valid_1's auc: 0.773798
# [500]	training's binary_logloss: 0.231074	training's auc: 0.805987	valid_1's binary_logloss: 0.240718	valid_1's auc: 0.775516
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.231074	training's auc: 0.805987	valid_1's binary_logloss: 0.240718	valid_1's auc: 0.775516
# |  2        |  0.7755   |  0.6917   |  397.9    |  11.29    |  117.9    |  46.35    |  26.84    |  4.366    |  0.2023   |  0.9163   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's binary_logloss: 0.243857	training's auc: 0.775771	valid_1's binary_logloss: 0.247976	valid_1's auc: 0.757236
# [200]	training's binary_logloss: 0.235046	training's auc: 0.796879	valid_1's binary_logloss: 0.243186	valid_1's auc: 0.768865
# [300]	training's binary_logloss: 0.22933	training's auc: 0.812083	valid_1's binary_logloss: 0.241565	valid_1's auc: 0.773432
# [400]	training's binary_logloss: 0.224499	training's auc: 0.824867	valid_1's binary_logloss: 0.24057	valid_1's auc: 0.776305
# [500]	training's binary_logloss: 0.220438	training's auc: 0.835706	valid_1's binary_logloss: 0.240148	valid_1's auc: 0.77742
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.220438	training's auc: 0.835706	valid_1's binary_logloss: 0.240148	valid_1's auc: 0.77742
# |  3        |  0.7774   |  0.8891   |  436.3    |  15.79    |  161.8    |  23.61    |  55.22    |  5.923    |  6.399    |  0.5717   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's binary_logloss: 0.24689	training's auc: 0.765645	valid_1's binary_logloss: 0.249302	valid_1's auc: 0.753405
# [200]	training's binary_logloss: 0.239789	training's auc: 0.782943	valid_1's binary_logloss: 0.244617	valid_1's auc: 0.764949
# [300]	training's binary_logloss: 0.23574	training's auc: 0.793768	valid_1's binary_logloss: 0.242652	valid_1's auc: 0.770495
# [400]	training's binary_logloss: 0.232816	training's auc: 0.801653	valid_1's binary_logloss: 0.241671	valid_1's auc: 0.773194
# [500]	training's binary_logloss: 0.230346	training's auc: 0.808306	valid_1's binary_logloss: 0.241046	valid_1's auc: 0.774952
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.230346	training's auc: 0.808306	valid_1's binary_logloss: 0.241046	valid_1's auc: 0.774952
# |  4        |  0.775    |  0.9723   |  265.7    |  10.15    |  60.27    |  38.94    |  42.25    |  28.43    |  0.188    |  0.8088   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's binary_logloss: 0.247344	training's auc: 0.76537	valid_1's binary_logloss: 0.249705	valid_1's auc: 0.753319
# [200]	training's binary_logloss: 0.240368	training's auc: 0.78148	valid_1's binary_logloss: 0.244951	valid_1's auc: 0.764227
# [300]	training's binary_logloss: 0.236522	training's auc: 0.791591	valid_1's binary_logloss: 0.243046	valid_1's auc: 0.769497
# [400]	training's binary_logloss: 0.233772	training's auc: 0.799043	valid_1's binary_logloss: 0.242148	valid_1's auc: 0.772037
# [500]	training's binary_logloss: 0.231408	training's auc: 0.805572	valid_1's binary_logloss: 0.241485	valid_1's auc: 0.773958
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.231408	training's auc: 0.805572	valid_1's binary_logloss: 0.241485	valid_1's auc: 0.773958
# |  5        |  0.774    |  0.806    |  312.3    |  15.44    |  139.5    |  18.62    |  41.48    |  34.88    |  0.6023   |  0.8334   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's binary_logloss: 0.24732	training's auc: 0.765825	valid_1's binary_logloss: 0.249545	valid_1's auc: 0.753516
# [200]	training's binary_logloss: 0.24043	training's auc: 0.781905	valid_1's binary_logloss: 0.244723	valid_1's auc: 0.764942
# [300]	training's binary_logloss: 0.236732	training's auc: 0.791364	valid_1's binary_logloss: 0.242806	valid_1's auc: 0.770074
# [400]	training's binary_logloss: 0.234063	training's auc: 0.798377	valid_1's binary_logloss: 0.241838	valid_1's auc: 0.772719
# [500]	training's binary_logloss: 0.231891	training's auc: 0.804221	valid_1's binary_logloss: 0.241215	valid_1's auc: 0.774525
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.231891	training's auc: 0.804221	valid_1's binary_logloss: 0.241215	valid_1's auc: 0.774525
# |  6        |  0.7745   |  0.8538   |  499.2    |  7.119    |  10.4     |  37.64    |  46.75    |  34.55    |  7.535    |  0.7468   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's binary_logloss: 0.246674	training's auc: 0.770041	valid_1's binary_logloss: 0.249352	valid_1's auc: 0.756019
# [200]	training's binary_logloss: 0.239243	training's auc: 0.785735	valid_1's binary_logloss: 0.244477	valid_1's auc: 0.765909
# [300]	training's binary_logloss: 0.235035	training's auc: 0.796567	valid_1's binary_logloss: 0.242613	valid_1's auc: 0.770756
# [400]	training's binary_logloss: 0.231813	training's auc: 0.805108	valid_1's binary_logloss: 0.241614	valid_1's auc: 0.773538
# [500]	training's binary_logloss: 0.229112	training's auc: 0.812452	valid_1's binary_logloss: 0.241039	valid_1's auc: 0.775111
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.229112	training's auc: 0.812452	valid_1's binary_logloss: 0.241039	valid_1's auc: 0.775111
# |  7        |  0.7751   |  0.6299   |  489.8    |  15.31    |  199.0    |  45.2     |  51.84    |  29.76    |  4.925    |  0.5147   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's binary_logloss: 0.249144	training's auc: 0.756515	valid_1's binary_logloss: 0.250158	valid_1's auc: 0.750087
# [200]	training's binary_logloss: 0.242814	training's auc: 0.773158	valid_1's binary_logloss: 0.245508	valid_1's auc: 0.761969
# [300]	training's binary_logloss: 0.239364	training's auc: 0.782773	valid_1's binary_logloss: 0.243766	valid_1's auc: 0.766779
# [400]	training's binary_logloss: 0.236893	training's auc: 0.789851	valid_1's binary_logloss: 0.242908	valid_1's auc: 0.76919
# [500]	training's binary_logloss: 0.234803	training's auc: 0.796017	valid_1's binary_logloss: 0.242331	valid_1's auc: 0.770892
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.234803	training's auc: 0.796017	valid_1's binary_logloss: 0.242331	valid_1's auc: 0.770892
# |  8        |  0.7709   |  0.8966   |  15.01    |  13.88    |  196.1    |  7.01     |  24.9     |  3.115    |  9.498    |  0.6352   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's binary_logloss: 0.247997	training's auc: 0.759811	valid_1's binary_logloss: 0.249427	valid_1's auc: 0.7519
# [200]	training's binary_logloss: 0.241157	training's auc: 0.778038	valid_1's binary_logloss: 0.244533	valid_1's auc: 0.765007
# [300]	training's binary_logloss: 0.237184	training's auc: 0.789001	valid_1's binary_logloss: 0.242428	valid_1's auc: 0.771145
# [400]	training's binary_logloss: 0.234342	training's auc: 0.796935	valid_1's binary_logloss: 0.241357	valid_1's auc: 0.774175
# [500]	training's binary_logloss: 0.232041	training's auc: 0.80335	valid_1's binary_logloss: 0.240763	valid_1's auc: 0.775796
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.232041	training's auc: 0.80335	valid_1's binary_logloss: 0.240763	valid_1's auc: 0.775796
# |  9        |  0.7758   |  0.9961   |  483.0    |  11.63    |  198.1    |  3.212    |  24.7     |  4.527    |  9.166    |  0.9857   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's binary_logloss: 0.243025	training's auc: 0.778263	valid_1's binary_logloss: 0.247712	valid_1's auc: 0.757941
# [200]	training's binary_logloss: 0.234055	training's auc: 0.799906	valid_1's binary_logloss: 0.243198	valid_1's auc: 0.768635
# [300]	training's binary_logloss: 0.228197	training's auc: 0.814992	valid_1's binary_logloss: 0.241626	valid_1's auc: 0.772943
# [400]	training's binary_logloss: 0.223434	training's auc: 0.827572	valid_1's binary_logloss: 0.240852	valid_1's auc: 0.775155
# [500]	training's binary_logloss: 0.218962	training's auc: 0.839415	valid_1's binary_logloss: 0.24029	valid_1's auc: 0.776832
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.218962	training's auc: 0.839415	valid_1's binary_logloss: 0.24029	valid_1's auc: 0.776832
# |  10       |  0.7768   |  0.9175   |  493.6    |  7.915    |  26.85    |  5.948    |  56.54    |  5.108    |  0.04135  |  0.6593   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's binary_logloss: 0.243834	training's auc: 0.778565	valid_1's binary_logloss: 0.24789	valid_1's auc: 0.759458
# [200]	training's binary_logloss: 0.235342	training's auc: 0.79721	valid_1's binary_logloss: 0.243275	valid_1's auc: 0.768717
# [300]	training's binary_logloss: 0.230344	training's auc: 0.80983	valid_1's binary_logloss: 0.241649	valid_1's auc: 0.772908
# [400]	training's binary_logloss: 0.226625	training's auc: 0.819452	valid_1's binary_logloss: 0.240833	valid_1's auc: 0.775153
# [500]	training's binary_logloss: 0.223319	training's auc: 0.828219	valid_1's binary_logloss: 0.240372	valid_1's auc: 0.776488
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.223319	training's auc: 0.828219	valid_1's binary_logloss: 0.240372	valid_1's auc: 0.776488
# |  11       |  0.7765   |  0.6056   |  499.7    |  6.601    |  13.13    |  24.1     |  58.26    |  5.517    |  0.5138   |  0.647    |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's binary_logloss: 0.24446	training's auc: 0.775224	valid_1's binary_logloss: 0.248202	valid_1's auc: 0.756636
# [200]	training's binary_logloss: 0.236708	training's auc: 0.793619	valid_1's binary_logloss: 0.243791	valid_1's auc: 0.767074
# [300]	training's binary_logloss: 0.232456	training's auc: 0.804179	valid_1's binary_logloss: 0.242083	valid_1's auc: 0.77151
# [400]	training's binary_logloss: 0.229547	training's auc: 0.811587	valid_1's binary_logloss: 0.241243	valid_1's auc: 0.773766
# [500]	training's binary_logloss: 0.227259	training's auc: 0.817651	valid_1's binary_logloss: 0.240815	valid_1's auc: 0.774899
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.227259	training's auc: 0.817651	valid_1's binary_logloss: 0.240815	valid_1's auc: 0.774899
# |  12       |  0.7749   |  0.8912   |  494.2    |  6.393    |  183.3    |  39.2     |  62.53    |  1.635    |  0.398    |  0.6643   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's binary_logloss: 0.249341	training's auc: 0.761845	valid_1's binary_logloss: 0.250731	valid_1's auc: 0.753198
# [200]	training's binary_logloss: 0.242899	training's auc: 0.774505	valid_1's binary_logloss: 0.245793	valid_1's auc: 0.762374
# [300]	training's binary_logloss: 0.239625	training's auc: 0.782803	valid_1's binary_logloss: 0.243783	valid_1's auc: 0.767513
# [400]	training's binary_logloss: 0.23739	training's auc: 0.788812	valid_1's binary_logloss: 0.242648	valid_1's auc: 0.770686
# [500]	training's binary_logloss: 0.235679	training's auc: 0.793494	valid_1's binary_logloss: 0.241994	valid_1's auc: 0.772554
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.235679	training's auc: 0.793494	valid_1's binary_logloss: 0.241994	valid_1's auc: 0.772554
# |  13       |  0.7726   |  0.5404   |  489.0    |  13.8     |  23.07    |  8.96     |  31.08    |  49.92    |  9.253    |  0.7969   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's binary_logloss: 0.242598	training's auc: 0.780144	valid_1's binary_logloss: 0.247434	valid_1's auc: 0.759083
# [200]	training's binary_logloss: 0.232943	training's auc: 0.803126	valid_1's binary_logloss: 0.242735	valid_1's auc: 0.770009
# [300]	training's binary_logloss: 0.226502	training's auc: 0.819728	valid_1's binary_logloss: 0.241206	valid_1's auc: 0.77406
# [400]	training's binary_logloss: 0.221168	training's auc: 0.833653	valid_1's binary_logloss: 0.240387	valid_1's auc: 0.776396
# [500]	training's binary_logloss: 0.216659	training's auc: 0.845401	valid_1's binary_logloss: 0.239973	valid_1's auc: 0.77771
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.216659	training's auc: 0.845401	valid_1's binary_logloss: 0.239973	valid_1's auc: 0.77771
# |  14       |  0.7777   |  0.8517   |  491.3    |  13.98    |  172.8    |  46.93    |  62.31    |  0.6367   |  7.261    |  0.875    |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's binary_logloss: 0.242957	training's auc: 0.780041	valid_1's binary_logloss: 0.247544	valid_1's auc: 0.759819
# [200]	training's binary_logloss: 0.23366	training's auc: 0.801221	valid_1's binary_logloss: 0.242845	valid_1's auc: 0.769869
# [300]	training's binary_logloss: 0.227558	training's auc: 0.817018	valid_1's binary_logloss: 0.24124	valid_1's auc: 0.774159
# [400]	training's binary_logloss: 0.222367	training's auc: 0.830611	valid_1's binary_logloss: 0.24033	valid_1's auc: 0.776733
# [500]	training's binary_logloss: 0.217895	training's auc: 0.842128	valid_1's binary_logloss: 0.239864	valid_1's auc: 0.778072
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.217895	training's auc: 0.842128	valid_1's binary_logloss: 0.239864	valid_1's auc: 0.778072
# |  15       |  0.7781   |  0.7017   |  490.7    |  13.93    |  185.9    |  47.78    |  62.17    |  4.098    |  3.805    |  0.7952   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's binary_logloss: 0.242704	training's auc: 0.779864	valid_1's binary_logloss: 0.247543	valid_1's auc: 0.758587
# [200]	training's binary_logloss: 0.233121	training's auc: 0.80269	valid_1's binary_logloss: 0.242865	valid_1's auc: 0.769613
# [300]	training's binary_logloss: 0.22666	training's auc: 0.819396	valid_1's binary_logloss: 0.241293	valid_1's auc: 0.773988
# [400]	training's binary_logloss: 0.221377	training's auc: 0.833116	valid_1's binary_logloss: 0.240489	valid_1's auc: 0.776266
# [500]	training's binary_logloss: 0.216831	training's auc: 0.84489	valid_1's binary_logloss: 0.240067	valid_1's auc: 0.77755
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.216831	training's auc: 0.84489	valid_1's binary_logloss: 0.240067	valid_1's auc: 0.77755
# |  16       |  0.7776   |  0.879    |  487.3    |  13.74    |  22.79    |  47.05    |  63.32    |  1.131    |  9.356    |  0.8718   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's binary_logloss: 0.243331	training's auc: 0.779629	valid_1's binary_logloss: 0.247732	valid_1's auc: 0.759689
# [200]	training's binary_logloss: 0.23417	training's auc: 0.800113	valid_1's binary_logloss: 0.242927	valid_1's auc: 0.769677
# [300]	training's binary_logloss: 0.228204	training's auc: 0.815559	valid_1's binary_logloss: 0.241337	valid_1's auc: 0.773849
# [400]	training's binary_logloss: 0.223179	training's auc: 0.828565	valid_1's binary_logloss: 0.240437	valid_1's auc: 0.776335
# [500]	training's binary_logloss: 0.218805	training's auc: 0.840011	valid_1's binary_logloss: 0.240029	valid_1's auc: 0.777463
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.218805	training's auc: 0.840011	valid_1's binary_logloss: 0.240029	valid_1's auc: 0.777463
# |  17       |  0.7775   |  0.67     |  493.4    |  12.61    |  26.38    |  40.66    |  61.3     |  4.579    |  5.896    |  0.509    |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's binary_logloss: 0.242845	training's auc: 0.780443	valid_1's binary_logloss: 0.247503	valid_1's auc: 0.759076
# [200]	training's binary_logloss: 0.233705	training's auc: 0.801604	valid_1's binary_logloss: 0.242943	valid_1's auc: 0.7694
# [300]	training's binary_logloss: 0.22831	training's auc: 0.815016	valid_1's binary_logloss: 0.241496	valid_1's auc: 0.773104
# [400]	training's binary_logloss: 0.224336	training's auc: 0.825247	valid_1's binary_logloss: 0.240726	valid_1's auc: 0.775234
# [500]	training's binary_logloss: 0.220909	training's auc: 0.834136	valid_1's binary_logloss: 0.240301	valid_1's auc: 0.776517
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.220909	training's auc: 0.834136	valid_1's binary_logloss: 0.240301	valid_1's auc: 0.776517
# |  18       |  0.7765   |  0.861    |  474.7    |  7.911    |  147.3    |  42.32    |  63.62    |  0.9772   |  9.149    |  0.6665   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's binary_logloss: 0.241974	training's auc: 0.78343	valid_1's binary_logloss: 0.247443	valid_1's auc: 0.760598
# [200]	training's binary_logloss: 0.231879	training's auc: 0.806507	valid_1's binary_logloss: 0.242798	valid_1's auc: 0.769842
# [300]	training's binary_logloss: 0.224859	training's auc: 0.824907	valid_1's binary_logloss: 0.241188	valid_1's auc: 0.774155
# [400]	training's binary_logloss: 0.219027	training's auc: 0.840281	valid_1's binary_logloss: 0.24038	valid_1's auc: 0.776506
# [500]	training's binary_logloss: 0.214051	training's auc: 0.853207	valid_1's binary_logloss: 0.240033	valid_1's auc: 0.777452
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.214051	training's auc: 0.853207	valid_1's binary_logloss: 0.240033	valid_1's auc: 0.777452
# |  19       |  0.7775   |  0.6257   |  473.8    |  15.83    |  31.5     |  11.05    |  63.18    |  1.061    |  2.201    |  0.7491   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's binary_logloss: 0.243613	training's auc: 0.77535	valid_1's binary_logloss: 0.247619	valid_1's auc: 0.757717
# [200]	training's binary_logloss: 0.234797	training's auc: 0.796978	valid_1's binary_logloss: 0.243032	valid_1's auc: 0.768848
# [300]	training's binary_logloss: 0.22921	training's auc: 0.811471	valid_1's binary_logloss: 0.241435	valid_1's auc: 0.773177
# [400]	training's binary_logloss: 0.22471	training's auc: 0.823435	valid_1's binary_logloss: 0.240676	valid_1's auc: 0.775436
# [500]	training's binary_logloss: 0.220889	training's auc: 0.833725	valid_1's binary_logloss: 0.240192	valid_1's auc: 0.776949
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.220889	training's auc: 0.833725	valid_1's binary_logloss: 0.240192	valid_1's auc: 0.776949
# |  20       |  0.7769   |  0.9651   |  498.9    |  10.43    |  18.86    |  49.85    |  51.33    |  0.999    |  2.755    |  0.7083   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's binary_logloss: 0.243251	training's auc: 0.779905	valid_1's binary_logloss: 0.247624	valid_1's auc: 0.759509
# [200]	training's binary_logloss: 0.23435	training's auc: 0.799787	valid_1's binary_logloss: 0.243073	valid_1's auc: 0.769044
# [300]	training's binary_logloss: 0.229156	training's auc: 0.81286	valid_1's binary_logloss: 0.24156	valid_1's auc: 0.772971
# [400]	training's binary_logloss: 0.225143	training's auc: 0.823197	valid_1's binary_logloss: 0.240818	valid_1's auc: 0.77502
# [500]	training's binary_logloss: 0.221589	training's auc: 0.83237	valid_1's binary_logloss: 0.240404	valid_1's auc: 0.776257
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.221589	training's auc: 0.83237	valid_1's binary_logloss: 0.240404	valid_1's auc: 0.776257
# |  21       |  0.7763   |  0.7307   |  497.6    |  7.704    |  43.93    |  49.29    |  62.3     |  2.761    |  6.592    |  0.7549   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's binary_logloss: 0.242126	training's auc: 0.781755	valid_1's binary_logloss: 0.247565	valid_1's auc: 0.758176
# [200]	training's binary_logloss: 0.232576	training's auc: 0.805366	valid_1's binary_logloss: 0.243137	valid_1's auc: 0.768849
# [300]	training's binary_logloss: 0.226525	training's auc: 0.820963	valid_1's binary_logloss: 0.241592	valid_1's auc: 0.773048
# [400]	training's binary_logloss: 0.222043	training's auc: 0.832628	valid_1's binary_logloss: 0.240778	valid_1's auc: 0.775467
# [500]	training's binary_logloss: 0.217934	training's auc: 0.84375	valid_1's binary_logloss: 0.240313	valid_1's auc: 0.776785
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.217934	training's auc: 0.84375	valid_1's binary_logloss: 0.240313	valid_1's auc: 0.776785
# |  22       |  0.7768   |  0.9702   |  490.2    |  6.676    |  130.6    |  1.011    |  62.38    |  1.419    |  0.3262   |  0.5556   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's binary_logloss: 0.242539	training's auc: 0.77961	valid_1's binary_logloss: 0.247389	valid_1's auc: 0.758656
# [200]	training's binary_logloss: 0.232824	training's auc: 0.803156	valid_1's binary_logloss: 0.242678	valid_1's auc: 0.770106
# [300]	training's binary_logloss: 0.226251	training's auc: 0.820165	valid_1's binary_logloss: 0.241052	valid_1's auc: 0.774524
# [400]	training's binary_logloss: 0.22086	training's auc: 0.834272	valid_1's binary_logloss: 0.240255	valid_1's auc: 0.77685
# [500]	training's binary_logloss: 0.216277	training's auc: 0.84602	valid_1's binary_logloss: 0.239947	valid_1's auc: 0.777788
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.216277	training's auc: 0.84602	valid_1's binary_logloss: 0.239947	valid_1's auc: 0.777788
# |  23       |  0.7778   |  0.9377   |  491.2    |  13.94    |  186.9    |  43.18    |  62.04    |  0.7011   |  6.74     |  0.6372   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's binary_logloss: 0.242289	training's auc: 0.780708	valid_1's binary_logloss: 0.247316	valid_1's auc: 0.759144
# [200]	training's binary_logloss: 0.232784	training's auc: 0.803384	valid_1's binary_logloss: 0.242767	valid_1's auc: 0.769872
# [300]	training's binary_logloss: 0.226826	training's auc: 0.818507	valid_1's binary_logloss: 0.241373	valid_1's auc: 0.773528
# [400]	training's binary_logloss: 0.222329	training's auc: 0.830163	valid_1's binary_logloss: 0.240655	valid_1's auc: 0.775672
# [500]	training's binary_logloss: 0.218522	training's auc: 0.840134	valid_1's binary_logloss: 0.240205	valid_1's auc: 0.777063
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.218522	training's auc: 0.840134	valid_1's binary_logloss: 0.240205	valid_1's auc: 0.777063
# |  24       |  0.7771   |  0.9335   |  495.5    |  9.276    |  21.97    |  43.59    |  63.13    |  0.3813   |  4.526    |  0.5504   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's binary_logloss: 0.244371	training's auc: 0.775597	valid_1's binary_logloss: 0.248209	valid_1's auc: 0.756485
# [200]	training's binary_logloss: 0.236377	training's auc: 0.794781	valid_1's binary_logloss: 0.243787	valid_1's auc: 0.766861
# [300]	training's binary_logloss: 0.231976	training's auc: 0.805692	valid_1's binary_logloss: 0.242147	valid_1's auc: 0.771191
# [400]	training's binary_logloss: 0.228999	training's auc: 0.813254	valid_1's binary_logloss: 0.241371	valid_1's auc: 0.773255
# [500]	training's binary_logloss: 0.226754	training's auc: 0.819114	valid_1's binary_logloss: 0.240925	valid_1's auc: 0.77454
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.226754	training's auc: 0.819114	valid_1's binary_logloss: 0.240925	valid_1's auc: 0.77454
# |  25       |  0.7745   |  0.9619   |  486.2    |  6.177    |  197.1    |  27.25    |  63.17    |  0.7311   |  5.497    |  0.6391   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's binary_logloss: 0.243645	training's auc: 0.779356	valid_1's binary_logloss: 0.247857	valid_1's auc: 0.759784
# [200]	training's binary_logloss: 0.234745	training's auc: 0.798626	valid_1's binary_logloss: 0.243061	valid_1's auc: 0.76939
# [300]	training's binary_logloss: 0.228948	training's auc: 0.813376	valid_1's binary_logloss: 0.241383	valid_1's auc: 0.773694
# [400]	training's binary_logloss: 0.224082	training's auc: 0.826149	valid_1's binary_logloss: 0.240454	valid_1's auc: 0.776226
# [500]	training's binary_logloss: 0.219815	training's auc: 0.837341	valid_1's binary_logloss: 0.240028	valid_1's auc: 0.777399
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.219815	training's auc: 0.837341	valid_1's binary_logloss: 0.240028	valid_1's auc: 0.777399
# |  26       |  0.7774   |  0.6638   |  478.1    |  14.14    |  19.42    |  47.59    |  62.23    |  7.326    |  5.151    |  0.8538   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's binary_logloss: 0.245459	training's auc: 0.770891	valid_1's binary_logloss: 0.248312	valid_1's auc: 0.757436
# [200]	training's binary_logloss: 0.237436	training's auc: 0.789611	valid_1's binary_logloss: 0.243448	valid_1's auc: 0.768098
# [300]	training's binary_logloss: 0.232474	training's auc: 0.802795	valid_1's binary_logloss: 0.24164	valid_1's auc: 0.77301
# [400]	training's binary_logloss: 0.228575	training's auc: 0.813297	valid_1's binary_logloss: 0.240714	valid_1's auc: 0.77566
# [500]	training's binary_logloss: 0.225327	training's auc: 0.822069	valid_1's binary_logloss: 0.240242	valid_1's auc: 0.777062
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.225327	training's auc: 0.822069	valid_1's binary_logloss: 0.240242	valid_1's auc: 0.777062
# |  27       |  0.7771   |  0.711    |  498.6    |  13.91    |  30.86    |  48.54    |  38.75    |  0.05326  |  5.271    |  0.7529   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's binary_logloss: 0.243061	training's auc: 0.779315	valid_1's binary_logloss: 0.247485	valid_1's auc: 0.76053
# [200]	training's binary_logloss: 0.233905	training's auc: 0.800052	valid_1's binary_logloss: 0.242844	valid_1's auc: 0.76986
# [300]	training's binary_logloss: 0.227816	training's auc: 0.815983	valid_1's binary_logloss: 0.24119	valid_1's auc: 0.774216
# [400]	training's binary_logloss: 0.222864	training's auc: 0.829098	valid_1's binary_logloss: 0.240437	valid_1's auc: 0.776296
# [500]	training's binary_logloss: 0.218622	training's auc: 0.840378	valid_1's binary_logloss: 0.240073	valid_1's auc: 0.777453
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.218622	training's auc: 0.840378	valid_1's binary_logloss: 0.240073	valid_1's auc: 0.777453
# |  28       |  0.7775   |  0.578    |  491.8    |  14.08    |  74.38    |  45.79    |  54.86    |  0.1397   |  0.5072   |  0.9501   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's binary_logloss: 0.244987	training's auc: 0.772567	valid_1's binary_logloss: 0.248141	valid_1's auc: 0.757704
# [200]	training's binary_logloss: 0.23679	training's auc: 0.791837	valid_1's binary_logloss: 0.243341	valid_1's auc: 0.768379
# [300]	training's binary_logloss: 0.231664	training's auc: 0.805093	valid_1's binary_logloss: 0.24155	valid_1's auc: 0.773274
# [400]	training's binary_logloss: 0.227576	training's auc: 0.816067	valid_1's binary_logloss: 0.240575	valid_1's auc: 0.77607
# [500]	training's binary_logloss: 0.224216	training's auc: 0.82516	valid_1's binary_logloss: 0.240169	valid_1's auc: 0.777168
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.224216	training's auc: 0.82516	valid_1's binary_logloss: 0.240169	valid_1's auc: 0.777168
# |  29       |  0.7772   |  0.7049   |  484.8    |  10.56    |  13.1     |  48.91    |  43.8     |  0.5117   |  9.967    |  0.7057   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's binary_logloss: 0.246189	training's auc: 0.769172	valid_1's binary_logloss: 0.248647	valid_1's auc: 0.756848
# [200]	training's binary_logloss: 0.238637	training's auc: 0.78625	valid_1's binary_logloss: 0.243807	valid_1's auc: 0.76704
# [300]	training's binary_logloss: 0.234064	training's auc: 0.798338	valid_1's binary_logloss: 0.241953	valid_1's auc: 0.772061
# [400]	training's binary_logloss: 0.230535	training's auc: 0.808063	valid_1's binary_logloss: 0.241013	valid_1's auc: 0.774793
# [500]	training's binary_logloss: 0.227408	training's auc: 0.816556	valid_1's binary_logloss: 0.240367	valid_1's auc: 0.776634
# Did not meet early stopping. Best iteration is:
# [500]	training's binary_logloss: 0.227408	training's auc: 0.816556	valid_1's binary_logloss: 0.240367	valid_1's auc: 0.776634
# |  30       |  0.7766   |  0.5828   |  498.0    |  13.54    |  12.4     |  47.17    |  35.67    |  3.86     |  3.115    |  0.5713   |
# =====================================================================================================================================

# %% [markdown]
# ##### Iteration 수행 결과 출력

# %%
# BayesianOptimization객체의 res는 iteration 수행 시마다 모든 함수 반환결과와 그때의 파라미터 결과값을 가지고 있음. 
lgbBO.res
# Out:
# [{'params': {'colsample_bytree': 0.7744067519636624,
#    'max_bin': 360.44278952248555,
#    'max_depth': 12.027633760716439,
#    'min_child_samples': 113.52780476941041,
#    'min_child_weight': 21.75908516760633,
#    'num_leaves': 49.835764522666246,
#    'reg_alpha': 21.884984691022,
#    'reg_lambda': 8.917740830520719,
#    'subsample': 0.9818313802505146},
#   'target': 0.775323078892067},
#  {'params': {'colsample_bytree': 0.6917207594128889,
#    'max_bin': 397.94526866050563,
#    'max_depth': 11.288949197529044,
#    'min_child_samples': 117.92846660784714,
#    'min_child_weight': 46.35423527634039,
#    'num_leaves': 26.841442327915477,
#    'reg_alpha': 4.36559369208002,
#    'reg_lambda': 0.20228195256351317,
#    'subsample': 0.916309922773969},
#   'target': 0.7755162165806446},
#  {'params': {'colsample_bytree': 0.8890783754749252,
#    'max_bin': 436.30595264094137,
#    'max_depth': 15.78618342232764,
#    'min_child_samples': 161.8401272011775,
#    'min_child_weight': 23.61248875039366,
#    'num_leaves': 55.22116705145822,
#    'reg_alpha': 5.922538549187972,
#    'reg_lambda': 6.399246221173105,
#    'subsample': 0.5716766437045232},
#   'target': 0.7774199354263552},
#  {'params': {'colsample_bytree': 0.972334458524792,
#    'max_bin': 265.70567765753515,
#    'max_depth': 10.146619399905235,
#    'min_child_samples': 60.265566299879126,
#    'min_child_weight': 38.93745078227661,
#    'num_leaves': 42.24601328866194,
#    'reg_alpha': 28.426013103943742,
#    'reg_lambda': 0.18799612538350777,
#    'subsample': 0.8088177485379385},
#   'target': 0.7749519255308448},
#  {'params': {'colsample_bytree': 0.8060478613612108,
#    'max_bin': 312.2976584686309,
#    'max_depth': 15.437480785146242,
#    'min_child_samples': 139.54585682966186,
#    'min_child_weight': 18.615887128115514,
#    'num_leaves': 41.481278151973655,
#    'reg_alpha': 34.88458348440397,
#    'reg_lambda': 0.6023486937455355,
#    'subsample': 0.8333833577228338},
#   'target': 0.7739575656186722},
#  {'params': {'colsample_bytree': 0.8538298637688885,
#    'max_bin': 499.18172097104025,
#    'max_depth': 7.1187205183646585,
#    'min_child_samples': 10.40382501514027,
#    'min_child_weight': 37.64143876594502,
#    'num_leaves': 46.751076731952274,
#    'reg_alpha': 34.54679765680322,
#    'reg_lambda': 7.535274995760495,
#    'subsample': 0.7467532758879181},
#   'target': 0.774525286125657},
#  {'params': {'colsample_bytree': 0.6299244772566623,
#    'max_bin': 489.7739785343305,
#    'max_depth': 15.314318039853122,
#    'min_child_samples': 199.03904563738396,
#    'min_child_weight': 45.201002594498284,
#    'num_leaves': 51.83814577401314,
#    'reg_alpha': 29.75720410406666,
#    'reg_lambda': 4.924809179993732,
#    'subsample': 0.5147380333972666},
#   'target': 0.7751107765898098},
#  {'params': {'colsample_bytree': 0.8966333260286151,
#    'max_bin': 15.00948474965021,
#    'max_depth': 13.881909966306875,
#    'min_child_samples': 196.09857006155036,
#    'min_child_weight': 7.010476192314001,
#    'num_leaves': 24.902246321496513,
#    'reg_alpha': 3.1154487379315183,
#    'reg_lambda': 9.498219782779769,
#    'subsample': 0.6352180121128941},
#   'target': 0.7708918707509925},
#  {'params': {'colsample_bytree': 0.9961136423812205,
#    'max_bin': 482.9550668804919,
#    'max_depth': 11.62539793072904,
#    'min_child_samples': 198.11792907221866,
#    'min_child_weight': 3.2117490664030814,
#    'num_leaves': 24.6998002479116,
#    'reg_alpha': 4.526845488516717,
#    'reg_lambda': 9.165786031693472,
#    'subsample': 0.9857139746615959},
#   'target': 0.7757964138752356},
#  {'params': {'colsample_bytree': 0.9175164419188413,
#    'max_bin': 493.5658079605351,
#    'max_depth': 7.915043818979178,
#    'min_child_samples': 26.848782127987075,
#    'min_child_weight': 5.948277743522355,
#    'num_leaves': 56.53770888028942,
#    'reg_alpha': 5.10751327753031,
#    'reg_lambda': 0.0413455836866224,
#    'subsample': 0.6593442087987207},
#   'target': 0.7768317620751318},
#  {'params': {'colsample_bytree': 0.6055808726670302,
#    'max_bin': 499.68853269091665,
#    'max_depth': 6.60126620503299,
#    'min_child_samples': 13.131425298842766,
#    'min_child_weight': 24.10349800336823,
#    'num_leaves': 58.25761397970154,
#    'reg_alpha': 5.5168074189476135,
#    'reg_lambda': 0.5138116887492082,
#    'subsample': 0.6470141329579027},
#   'target': 0.7764882254543516},
#  {'params': {'colsample_bytree': 0.8912022615867841,
#    'max_bin': 494.15804527027376,
#    'max_depth': 6.393327084680852,
#    'min_child_samples': 183.27577480919874,
#    'min_child_weight': 39.19821210251201,
#    'num_leaves': 62.532057720628906,
#    'reg_alpha': 1.6348690431607595,
#    'reg_lambda': 0.39800919001194407,
#    'subsample': 0.6642554583971336},
#   'target': 0.7748992986915725},
#  {'params': {'colsample_bytree': 0.54044461505982,
#    'max_bin': 488.98087033682907,
#    'max_depth': 13.798365840424696,
#    'min_child_samples': 23.07175350209438,
#    'min_child_weight': 8.960431348799812,
#    'num_leaves': 31.082399869743035,
#    'reg_alpha': 49.92357702887185,
#    'reg_lambda': 9.252885137374594,
#    'subsample': 0.7969124299878458},
#   'target': 0.7725543553198448},
#  {'params': {'colsample_bytree': 0.8517375014195105,
#    'max_bin': 491.2711570396746,
#    'max_depth': 13.977897376205249,
#    'min_child_samples': 172.76830537730496,
#    'min_child_weight': 46.929763528602514,
#    'num_leaves': 62.313227295911,
#    'reg_alpha': 0.6367280063423352,
#    'reg_lambda': 7.260733612575146,
#    'subsample': 0.8749622789612064},
#   'target': 0.7777103194318891},
#  {'params': {'colsample_bytree': 0.7017423803055269,
#    'max_bin': 490.65684311388475,
#    'max_depth': 13.925500717089148,
#    'min_child_samples': 185.8755926611623,
#    'min_child_weight': 47.781457981642575,
#    'num_leaves': 62.16673679819848,
#    'reg_alpha': 4.0980337454553775,
#    'reg_lambda': 3.8048953484080705,
#    'subsample': 0.7952444721248546},
#   'target': 0.7780715799448732},
#  {'params': {'colsample_bytree': 0.878984166735569,
#    'max_bin': 487.319455209816,
#    'max_depth': 13.74347971689194,
#    'min_child_samples': 22.793854301098456,
#    'min_child_weight': 47.051313468761144,
#    'num_leaves': 63.32449765350978,
#    'reg_alpha': 1.131005525995249,
#    'reg_lambda': 9.355976362329042,
#    'subsample': 0.8717664011361355},
#   'target': 0.7775503818751405},
#  {'params': {'colsample_bytree': 0.6699609259211681,
#    'max_bin': 493.44862677325995,
#    'max_depth': 12.6067511230441,
#    'min_child_samples': 26.37718858225197,
#    'min_child_weight': 40.65953318068241,
#    'num_leaves': 61.29693469421312,
#    'reg_alpha': 4.578538266986408,
#    'reg_lambda': 5.896187243905756,
#    'subsample': 0.5090345540442691},
#   'target': 0.777463344507386},
#  {'params': {'colsample_bytree': 0.8609646585570127,
#    'max_bin': 474.69974793416304,
#    'max_depth': 7.911390485387797,
#    'min_child_samples': 147.26538301366216,
#    'min_child_weight': 42.32040735644124,
#    'num_leaves': 63.622621351802124,
#    'reg_alpha': 0.9772298442142145,
#    'reg_lambda': 9.14941459249657,
#    'subsample': 0.6665141347179393},
#   'target': 0.7765165681150963},
#  {'params': {'colsample_bytree': 0.6257062560105544,
#    'max_bin': 473.8331088294021,
#    'max_depth': 15.828216635500233,
#    'min_child_samples': 31.4954420261719,
#    'min_child_weight': 11.053622940575561,
#    'num_leaves': 63.179090946271174,
#    'reg_alpha': 1.0614655798435124,
#    'reg_lambda': 2.2008570105403966,
#    'subsample': 0.7490943840047772},
#   'target': 0.7774519902878598},
#  {'params': {'colsample_bytree': 0.9651046398156432,
#    'max_bin': 498.9229660171792,
#    'max_depth': 10.4331159114082,
#    'min_child_samples': 18.85520130124945,
#    'min_child_weight': 49.84789637779042,
#    'num_leaves': 51.32662341809476,
#    'reg_alpha': 0.9989703146431631,
#    'reg_lambda': 2.7547455274641206,
#    'subsample': 0.7083088304588991},
#   'target': 0.7769485669406366},
#  {'params': {'colsample_bytree': 0.7306833224982413,
#    'max_bin': 497.6429483962119,
#    'max_depth': 7.703617399780626,
#    'min_child_samples': 43.933314820516514,
#    'min_child_weight': 49.292873668988236,
#    'num_leaves': 62.29738922363282,
#    'reg_alpha': 2.760930627922642,
#    'reg_lambda': 6.592447904991381,
#    'subsample': 0.7548714507500771},
#   'target': 0.7762571095852131},
#  {'params': {'colsample_bytree': 0.9702051409369551,
#    'max_bin': 490.2468911528458,
#    'max_depth': 6.675646963122917,
#    'min_child_samples': 130.59760265574238,
#    'min_child_weight': 1.0107380385879603,
#    'num_leaves': 62.37894582515848,
#    'reg_alpha': 1.419040898790039,
#    'reg_lambda': 0.32623621433036065,
#    'subsample': 0.5555631966642643},
#   'target': 0.7767854937894079},
#  {'params': {'colsample_bytree': 0.9377376515227308,
#    'max_bin': 491.22689723569005,
#    'max_depth': 13.935173886008302,
#    'min_child_samples': 186.94164321238858,
#    'min_child_weight': 43.180551139680034,
#    'num_leaves': 62.03630932465709,
#    'reg_alpha': 0.701081297793042,
#    'reg_lambda': 6.739625054702216,
#    'subsample': 0.6371851740655619},
#   'target': 0.777788035792344},
#  {'params': {'colsample_bytree': 0.9335178880792802,
#    'max_bin': 495.4705853959828,
#    'max_depth': 9.275577008280285,
#    'min_child_samples': 21.97422388511532,
#    'min_child_weight': 43.58541175677125,
#    'num_leaves': 63.128263229486635,
#    'reg_alpha': 0.3813229629049955,
#    'reg_lambda': 4.525768335007454,
#    'subsample': 0.5503847974222735},
#   'target': 0.7770629367168111},
#  {'params': {'colsample_bytree': 0.9619085895364587,
#    'max_bin': 486.20645804245305,
#    'max_depth': 6.1769829039174775,
#    'min_child_samples': 197.14695505385757,
#    'min_child_weight': 27.2484419776611,
#    'num_leaves': 63.16616658308855,
#    'reg_alpha': 0.7310886566513478,
#    'reg_lambda': 5.496575446948094,
#    'subsample': 0.6391237451821883},
#   'target': 0.774539709224887},
#  {'params': {'colsample_bytree': 0.6637581182039965,
#    'max_bin': 478.1043158687786,
#    'max_depth': 14.143838192928582,
#    'min_child_samples': 19.416823523968596,
#    'min_child_weight': 47.588246099984744,
#    'num_leaves': 62.23191279604004,
#    'reg_alpha': 7.325958014492767,
#    'reg_lambda': 5.151409242027755,
#    'subsample': 0.8538381398189729},
#   'target': 0.7773986534127555},
#  {'params': {'colsample_bytree': 0.7109876331061463,
#    'max_bin': 498.59988751702707,
#    'max_depth': 13.907844730355897,
#    'min_child_samples': 30.8555943394801,
#    'min_child_weight': 48.53921503483817,
#    'num_leaves': 38.75437478065399,
#    'reg_alpha': 0.053261047401944976,
#    'reg_lambda': 5.27056690256663,
#    'subsample': 0.7529175146435909},
#   'target': 0.7770618883417569},
#  {'params': {'colsample_bytree': 0.577967519414983,
#    'max_bin': 491.7762184936829,
#    'max_depth': 14.084808954152964,
#    'min_child_samples': 74.38447762936097,
#    'min_child_weight': 45.79131406525251,
#    'num_leaves': 54.85540961741905,
#    'reg_alpha': 0.13966186659687613,
#    'reg_lambda': 0.5071619155158816,
#    'subsample': 0.9500649686085855},
#   'target': 0.7774533627061126},
#  {'params': {'colsample_bytree': 0.7048968334628858,
#    'max_bin': 484.82472602615434,
#    'max_depth': 10.55974479883751,
#    'min_child_samples': 13.095052894611987,
#    'min_child_weight': 48.907808701184535,
#    'num_leaves': 43.80076300813039,
#    'reg_alpha': 0.5116783103676071,
#    'reg_lambda': 9.966795526886763,
#    'subsample': 0.7057371801704698},
#   'target': 0.7771678425254511},
#  {'params': {'colsample_bytree': 0.5827991689232433,
#    'max_bin': 498.0219727979582,
#    'max_depth': 13.540347383013662,
#    'min_child_samples': 12.395596080908227,
#    'min_child_weight': 47.17264274329862,
#    'num_leaves': 35.67122270764378,
#    'reg_alpha': 3.8600833083778534,
#    'reg_lambda': 3.115054113751626,
#    'subsample': 0.5712624730414866},
#   'target': 0.7766342180344326}]

# %% [markdown]
# ##### Iteration 결과 Dictionary에서 최대 target값을 가지는 index 추출하고 그때의 parameter 값을 추출.

# %%
# dictionary에 있는 target값을 모두 추출
target_list = []
for result in lgbBO.res:
    target = result['target']
    target_list.append(target)
print(target_list)
# 가장 큰 target 값을 가지는 순번(index)를 추출
print('maximum target index:', np.argmax(np.array(target_list)))
# Out:
# [0.775323078892067, 0.7755162165806446, 0.7774199354263552, 0.7749519255308448, 0.7739575656186722, 0.774525286125657, 0.7751107765898098, 0.7708918707509925, 0.7757964138752356, 0.7768317620751318, 0.7764882254543516, 0.7748992986915725, 0.7725543553198448, 0.7777103194318891, 0.7780715799448732, 0.7775503818751405, 0.777463344507386, 0.7765165681150963, 0.7774519902878598, 0.7769485669406366, 0.7762571095852131, 0.7767854937894079, 0.777788035792344, 0.7770629367168111, 0.774539709224887, 0.7773986534127555, 0.7770618883417569, 0.7774533627061126, 0.7771678425254511, 0.7766342180344326]
# maximum target index: 14

# %%
# 가장 큰 target값을 가지는 index값을 기준으로 res에서 해당 parameter 추출. 
max_dict = lgbBO.res[np.argmax(np.array(target_list))]
print(max_dict)
# Out:
# {'target': 0.7780715799448732, 'params': {'colsample_bytree': 0.7017423803055269, 'max_bin': 490.65684311388475, 'max_depth': 13.925500717089148, 'min_child_samples': 185.8755926611623, 'min_child_weight': 47.781457981642575, 'num_leaves': 62.16673679819848, 'reg_alpha': 4.0980337454553775, 'reg_lambda': 3.8048953484080705, 'subsample': 0.7952444721248546}}

# %% [markdown]
# ##### 최적화된 하이퍼 파라미터를 기반으로 재 테스트

# %%
def train_apps_all(apps_all_train):
    ftr_app = apps_all_train.drop(['SK_ID_CURR', 'TARGET'], axis=1)
    target_app = apps_all_train['TARGET']

    train_x, valid_x, train_y, valid_y = train_test_split(ftr_app, target_app, test_size=0.3, random_state=2020)
    print('train shape:', train_x.shape, 'valid shape:', valid_x.shape)
    clf = LGBMClassifier(
                nthread=4,
                n_estimators=1000,
                learning_rate=0.02,
                max_depth = 13,
                num_leaves=62,
                colsample_bytree=0.701,
                subsample=0.682,
                max_bin=490,
                reg_alpha=4.098,
                reg_lambda=3.804,
                min_child_weight=47,
                min_child_samples=185,
                silent=-1,
                verbose=-1,
                )

    clf.fit(train_x, train_y, eval_set=[(train_x, train_y), (valid_x, valid_y)], eval_metric= 'auc', verbose= 100, 
                early_stopping_rounds= 100)
    
    return clf

# %%
apps_all = get_apps_all_with_prev_agg(apps, prev)
apps_all = get_apps_all_encoded(apps_all)
apps_all_train, apps_all_test = get_apps_all_train_test(apps_all)
clf = train_apps_all(apps_all_train)
# Out:
# prev_agg shape: (338857, 43)
# apps_all before merge shape: (356255, 135)
# apps_all after merge with prev_agg shape: (356255, 177)
# train shape: (215257, 175) valid shape: (92254, 175)
# Training until validation scores don't improve for 100 rounds.
# [100]	training's binary_logloss: 0.2429	training's auc: 0.780351	valid_1's binary_logloss: 0.247491	valid_1's auc: 0.76008
# [200]	training's binary_logloss: 0.233665	training's auc: 0.801338	valid_1's binary_logloss: 0.242836	valid_1's auc: 0.76994
# [300]	training's binary_logloss: 0.227596	training's auc: 0.81688	valid_1's binary_logloss: 0.241335	valid_1's auc: 0.773903
# [400]	training's binary_logloss: 0.222457	training's auc: 0.830451	valid_1's binary_logloss: 0.240454	valid_1's auc: 0.776474
# [500]	training's binary_logloss: 0.217953	training's auc: 0.842212	valid_1's binary_logloss: 0.239946	valid_1's auc: 0.777916
# [600]	training's binary_logloss: 0.213918	training's auc: 0.852499	valid_1's binary_logloss: 0.239706	valid_1's auc: 0.778572
# [700]	training's binary_logloss: 0.210219	training's auc: 0.861691	valid_1's binary_logloss: 0.239546	valid_1's auc: 0.779026
# [800]	training's binary_logloss: 0.20675	training's auc: 0.870048	valid_1's binary_logloss: 0.239532	valid_1's auc: 0.779047
# Early stopping, best iteration is:
# [780]	training's binary_logloss: 0.207435	training's auc: 0.868411	valid_1's binary_logloss: 0.239512	valid_1's auc: 0.779119

# %%
preds = clf.predict_proba(apps_all_test.drop('SK_ID_CURR', axis=1))[:, 1 ]
apps_all_test['TARGET'] = preds
# SK_ID_CURR과 TARGET 값만 csv 형태로 생성. 코랩 버전은 구글 드라이브 절대 경로로 입력  
default_dir = "/content/gdrive/MyDrive/ML/kaggle/home-credit-default-risk/data"
apps_all_test[['SK_ID_CURR', 'TARGET']].to_csv(os.path.join(default_dir,'prev_baseline_tuning_01.csv'), index=False)

# %%
apps_all_test.head()
# Out:
#         SK_ID_CURR  NAME_CONTRACT_TYPE  CODE_GENDER  FLAG_OWN_CAR  \
# 307511      100001                   0            1             0
# 307512      100005                   0            0             0
# 307513      100013                   0            0             1
# 307514      100028                   0            1             0
# 307515      100038                   0            0             1
#
#         FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# 307511                0             0          135000.0    568800.0
# 307512                0             0           99000.0    222768.0
# 307513                0             0          202500.0    663264.0
# 307514                0             2          315000.0   1575000.0
# 307515                1             1          180000.0    625500.0
#
#         AMT_ANNUITY  AMT_GOODS_PRICE  NAME_TYPE_SUITE  NAME_INCOME_TYPE  \
# 307511      20560.5         450000.0                0                 0
# 307512      17370.0         180000.0                0                 0
# 307513      69777.0         630000.0               -1                 0
# 307514      49018.5        1575000.0                0                 0
# 307515      32067.0         625500.0                0                 0
#
#         NAME_EDUCATION_TYPE  NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  \
# 307511                    1                   1                  0
# 307512                    0                   1                  0
# 307513                    1                   1                  0
# 307514                    0                   1                  0
# 307515                    0                   1                  0
#
#         REGION_POPULATION_RELATIVE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 307511                    0.018850      -19241          -2329
# 307512                    0.035792      -18064          -4469
# 307513                    0.019101      -20038          -4458
# 307514                    0.026392      -13976          -1866
# 307515                    0.010032      -13040          -2191
#
#         DAYS_REGISTRATION  DAYS_ID_PUBLISH  OWN_CAR_AGE  FLAG_MOBIL  \
# 307511            -5170.0             -812          NaN           1
# 307512            -9118.0            -1623          NaN           1
# 307513            -2175.0            -3503          5.0           1
# 307514            -2000.0            -4208          NaN           1
# 307515            -4000.0            -4262         16.0           1
#
#         FLAG_EMP_PHONE  FLAG_WORK_PHONE  FLAG_CONT_MOBILE  FLAG_PHONE  \
# 307511               1                0                 1           0
# 307512               1                0                 1           0
# 307513               1                0                 1           0
# 307514               1                0                 1           1
# 307515               1                1                 1           0
#
#         FLAG_EMAIL  OCCUPATION_TYPE  CNT_FAM_MEMBERS  REGION_RATING_CLIENT  \
# 307511           1               -1              2.0                     2
# 307512           0               13              2.0                     2
# 307513           0                4              2.0                     2
# 307514           0                5              4.0                     2
# 307515           0               -1              3.0                     2
#
#         REGION_RATING_CLIENT_W_CITY  WEEKDAY_APPR_PROCESS_START  \
# 307511                            2                           6
# 307512                            2                           5
# 307513                            2                           1
# 307514                            2                           0
# 307515                            2                           5
#
#         HOUR_APPR_PROCESS_START  REG_REGION_NOT_LIVE_REGION  \
# 307511                       18                           0
# 307512                        9                           0
# 307513                       14                           0
# 307514                       11                           0
# 307515                        5                           0
#
#         REG_REGION_NOT_WORK_REGION  LIVE_REGION_NOT_WORK_REGION  \
# 307511                           0                            0
# 307512                           0                            0
# 307513                           0                            0
# 307514                           0                            0
# 307515                           0                            0
#
#         REG_CITY_NOT_LIVE_CITY  REG_CITY_NOT_WORK_CITY  \
# 307511                       0                       0
# 307512                       0                       0
# 307513                       0                       0
# 307514                       0                       0
# 307515                       0                       1
#
#         LIVE_CITY_NOT_WORK_CITY  ORGANIZATION_TYPE  EXT_SOURCE_1  \
# 307511                        0                 13      0.752614
# 307512                        0                  9      0.564990
# 307513                        0                 25           NaN
# 307514                        0                  0      0.525734
# 307515                        1                  0      0.202145
#
#         EXT_SOURCE_2  EXT_SOURCE_3  APARTMENTS_AVG  BASEMENTAREA_AVG  \
# 307511      0.789654      0.159520          0.0660            0.0590
# 307512      0.291656      0.432962             NaN               NaN
# 307513      0.699787      0.610991             NaN               NaN
# 307514      0.509677      0.612704          0.3052            0.1974
# 307515      0.425687           NaN             NaN               NaN
#
#         YEARS_BEGINEXPLUATATION_AVG  YEARS_BUILD_AVG  COMMONAREA_AVG  \
# 307511                       0.9732              NaN             NaN
# 307512                          NaN              NaN             NaN
# 307513                          NaN              NaN             NaN
# 307514                       0.9970           0.9592          0.1165
# 307515                          NaN              NaN             NaN
#
#         ELEVATORS_AVG  ENTRANCES_AVG  FLOORSMAX_AVG  FLOORSMIN_AVG  \
# 307511            NaN         0.1379          0.125            NaN
# 307512            NaN            NaN            NaN            NaN
# 307513            NaN            NaN            NaN            NaN
# 307514           0.32         0.2759          0.375         0.0417
# 307515            NaN            NaN            NaN            NaN
#
#         LANDAREA_AVG  LIVINGAPARTMENTS_AVG  LIVINGAREA_AVG  \
# 307511           NaN                   NaN          0.0505
# 307512           NaN                   NaN             NaN
# 307513           NaN                   NaN             NaN
# 307514        0.2042                0.2404          0.3673
# 307515           NaN                   NaN             NaN
#
#         NONLIVINGAPARTMENTS_AVG  NONLIVINGAREA_AVG  APARTMENTS_MODE  \
# 307511                      NaN                NaN           0.0672
# 307512                      NaN                NaN              NaN
# 307513                      NaN                NaN              NaN
# 307514                   0.0386               0.08           0.3109
# 307515                      NaN                NaN              NaN
#
#         BASEMENTAREA_MODE  YEARS_BEGINEXPLUATATION_MODE  YEARS_BUILD_MODE  \
# 307511             0.0612                        0.9732               NaN
# 307512                NaN                           NaN               NaN
# 307513                NaN                           NaN               NaN
# 307514             0.2049                        0.9970            0.9608
# 307515                NaN                           NaN               NaN
#
#         COMMONAREA_MODE  ELEVATORS_MODE  ENTRANCES_MODE  FLOORSMAX_MODE  \
# 307511              NaN             NaN          0.1379           0.125
# 307512              NaN             NaN             NaN             NaN
# 307513              NaN             NaN             NaN             NaN
# 307514           0.1176          0.3222          0.2759           0.375
# 307515              NaN             NaN             NaN             NaN
#
#         FLOORSMIN_MODE  LANDAREA_MODE  LIVINGAPARTMENTS_MODE  LIVINGAREA_MODE  \
# 307511             NaN            NaN                    NaN           0.0526
# 307512             NaN            NaN                    NaN              NaN
# 307513             NaN            NaN                    NaN              NaN
# 307514          0.0417         0.2089                 0.2626           0.3827
# 307515             NaN            NaN                    NaN              NaN
#
#         NONLIVINGAPARTMENTS_MODE  NONLIVINGAREA_MODE  APARTMENTS_MEDI  \
# 307511                       NaN                 NaN           0.0666
# 307512                       NaN                 NaN              NaN
# 307513                       NaN                 NaN              NaN
# 307514                    0.0389              0.0847           0.3081
# 307515                       NaN                 NaN              NaN
#
#         BASEMENTAREA_MEDI  YEARS_BEGINEXPLUATATION_MEDI  YEARS_BUILD_MEDI  \
# 307511             0.0590                        0.9732               NaN
# 307512                NaN                           NaN               NaN
# 307513                NaN                           NaN               NaN
# 307514             0.1974                        0.9970            0.9597
# 307515                NaN                           NaN               NaN
#
#         COMMONAREA_MEDI  ELEVATORS_MEDI  ENTRANCES_MEDI  FLOORSMAX_MEDI  \
# 307511              NaN             NaN          0.1379           0.125
# 307512              NaN             NaN             NaN             NaN
# 307513              NaN             NaN             NaN             NaN
# 307514           0.1173            0.32          0.2759           0.375
# 307515              NaN             NaN             NaN             NaN
#
#         FLOORSMIN_MEDI  LANDAREA_MEDI  LIVINGAPARTMENTS_MEDI  LIVINGAREA_MEDI  \
# 307511             NaN            NaN                    NaN           0.0514
# 307512             NaN            NaN                    NaN              NaN
# 307513             NaN            NaN                    NaN              NaN
# 307514          0.0417         0.2078                 0.2446           0.3739
# 307515             NaN            NaN                    NaN              NaN
#
#         NONLIVINGAPARTMENTS_MEDI  NONLIVINGAREA_MEDI  FONDKAPREMONT_MODE  \
# 307511                       NaN                 NaN                  -1
# 307512                       NaN                 NaN                  -1
# 307513                       NaN                 NaN                  -1
# 307514                    0.0388              0.0817                   0
# 307515                       NaN                 NaN                  -1
#
#         HOUSETYPE_MODE  TOTALAREA_MODE  WALLSMATERIAL_MODE  \
# 307511               0          0.0392                   0
# 307512              -1             NaN                  -1
# 307513              -1             NaN                  -1
# 307514               0          0.3700                   2
# 307515              -1             NaN                  -1
#
#         EMERGENCYSTATE_MODE  OBS_30_CNT_SOCIAL_CIRCLE  \
# 307511                    0                       0.0
# 307512                   -1                       0.0
# 307513                   -1                       0.0
# 307514                    0                       0.0
# 307515                   -1                       0.0
#
#         DEF_30_CNT_SOCIAL_CIRCLE  OBS_60_CNT_SOCIAL_CIRCLE  \
# 307511                       0.0                       0.0
# 307512                       0.0                       0.0
# 307513                       0.0                       0.0
# 307514                       0.0                       0.0
# 307515                       0.0                       0.0
#
#         DEF_60_CNT_SOCIAL_CIRCLE  DAYS_LAST_PHONE_CHANGE  FLAG_DOCUMENT_2  \
# 307511                       0.0                 -1740.0                0
# 307512                       0.0                     0.0                0
# 307513                       0.0                  -856.0                0
# 307514                       0.0                 -1805.0                0
# 307515                       0.0                  -821.0                0
#
#         FLAG_DOCUMENT_3  FLAG_DOCUMENT_4  FLAG_DOCUMENT_5  FLAG_DOCUMENT_6  \
# 307511                1                0                0                0
# 307512                1                0                0                0
# 307513                0                0                0                0
# 307514                1                0                0                0
# 307515                1                0                0                0
#
#         FLAG_DOCUMENT_7  FLAG_DOCUMENT_8  FLAG_DOCUMENT_9  FLAG_DOCUMENT_10  \
# 307511                0                0                0                 0
# 307512                0                0                0                 0
# 307513                0                1                0                 0
# 307514                0                0                0                 0
# 307515                0                0                0                 0
#
#         FLAG_DOCUMENT_11  FLAG_DOCUMENT_12  FLAG_DOCUMENT_13  \
# 307511                 0                 0                 0
# 307512                 0                 0                 0
# 307513                 0                 0                 0
# 307514                 0                 0                 0
# 307515                 0                 0                 0
#
#         FLAG_DOCUMENT_14  FLAG_DOCUMENT_15  FLAG_DOCUMENT_16  \
# 307511                 0                 0                 0
# 307512                 0                 0                 0
# 307513                 0                 0                 0
# 307514                 0                 0                 0
# 307515                 0                 0                 0
#
#         FLAG_DOCUMENT_17  FLAG_DOCUMENT_18  FLAG_DOCUMENT_19  \
# 307511                 0                 0                 0
# 307512                 0                 0                 0
# 307513                 0                 0                 0
# 307514                 0                 0                 0
# 307515                 0                 0                 0
#
#         FLAG_DOCUMENT_20  FLAG_DOCUMENT_21  AMT_REQ_CREDIT_BUREAU_HOUR  \
# 307511                 0                 0                         0.0
# 307512                 0                 0                         0.0
# 307513                 0                 0                         0.0
# 307514                 0                 0                         0.0
# 307515                 0                 0                         NaN
#
#         AMT_REQ_CREDIT_BUREAU_DAY  AMT_REQ_CREDIT_BUREAU_WEEK  \
# 307511                        0.0                         0.0
# 307512                        0.0                         0.0
# 307513                        0.0                         0.0
# 307514                        0.0                         0.0
# 307515                        NaN                         NaN
#
#         AMT_REQ_CREDIT_BUREAU_MON  AMT_REQ_CREDIT_BUREAU_QRT  \
# 307511                        0.0                        0.0
# 307512                        0.0                        0.0
# 307513                        0.0                        1.0
# 307514                        0.0                        0.0
# 307515                        NaN                        NaN
#
#         AMT_REQ_CREDIT_BUREAU_YEAR  APPS_EXT_SOURCE_MEAN  APPS_EXT_SOURCE_STD  \
# 307511                         0.0              0.567263             0.353601
# 307512                         3.0              0.429869             0.136694
# 307513                         4.0              0.655389             0.062788
# 307514                         3.0              0.549372             0.055432
# 307515                         NaN              0.313916             0.158068
#
#         APPS_ANNUITY_CREDIT_RATIO  APPS_GOODS_CREDIT_RATIO  \
# 307511                   0.036147                 0.791139
# 307512                   0.077973                 0.808016
# 307513                   0.105202                 0.949848
# 307514                   0.031123                 1.000000
# 307515                   0.051266                 1.000000
#
#         APPS_ANNUITY_INCOME_RATIO  APPS_CREDIT_INCOME_RATIO  \
# 307511                   0.152300                  4.213333
# 307512                   0.175455                  2.250182
# 307513                   0.344578                  3.275378
# 307514                   0.155614                  5.000000
# 307515                   0.178150                  3.475000
#
#         APPS_GOODS_INCOME_RATIO  APPS_CNT_FAM_INCOME_RATIO  \
# 307511                 3.333333                    67500.0
# 307512                 1.818182                    49500.0
# 307513                 3.111111                   101250.0
# 307514                 5.000000                    78750.0
# 307515                 3.475000                    60000.0
#
#         APPS_EMPLOYED_BIRTH_RATIO  APPS_INCOME_EMPLOYED_RATIO  \
# 307511                   0.121044                  -57.964792
# 307512                   0.247398                  -22.152607
# 307513                   0.222477                  -45.423957
# 307514                   0.133515                 -168.810289
# 307515                   0.168021                  -82.154267
#
#         APPS_INCOME_BIRTH_RATIO  APPS_CAR_BIRTH_RATIO  \
# 307511                -7.016267                   NaN
# 307512                -5.480514                   NaN
# 307513               -10.105799             -0.000250
# 307514               -22.538638                   NaN
# 307515               -13.803681             -0.001227
#
#         APPS_CAR_EMPLOYED_RATIO  PREV_SK_ID_CURR_COUNT  PREV_AMT_CREDIT_MEAN  \
# 307511                      NaN                    1.0             23787.000
# 307512                      NaN                    2.0             20076.750
# 307513                -0.001122                    4.0            146134.125
# 307514                      NaN                    5.0             92920.500
# 307515                -0.007303                    2.0            300550.500
#
#         PREV_AMT_CREDIT_MAX  PREV_AMT_CREDIT_SUM  PREV_AMT_ANNUITY_MEAN  \
# 307511              23787.0              23787.0               3951.000
# 307512              40153.5              40153.5               4813.200
# 307513             512370.0             584536.5              11478.195
# 307514             225000.0             464602.5               8091.585
# 307515             508495.5             601101.0              17782.155
#
#         PREV_AMT_ANNUITY_MAX  PREV_AMT_ANNUITY_SUM  PREV_AMT_APPLICATION_MEAN  \
# 307511              3951.000              3951.000                   24835.50
# 307512              4813.200              4813.200                   22308.75
# 307513             23153.985             34434.585                  130871.25
# 307514             11250.000             24274.755                   49207.50
# 307515             24463.710             35564.310                  267727.50
#
#         PREV_AMT_APPLICATION_MAX  PREV_AMT_APPLICATION_SUM  \
# 307511                   24835.5                   24835.5
# 307512                   44617.5                   44617.5
# 307513                  450000.0                  523485.0
# 307514                  130765.5                  246037.5
# 307515                  454500.0                  535455.0
#
#         PREV_AMT_DOWN_PAYMENT_MEAN  PREV_AMT_DOWN_PAYMENT_MAX  \
# 307511                      2520.0                     2520.0
# 307512                      4464.0                     4464.0
# 307513                      3375.0                     6750.0
# 307514                      3750.0                    11250.0
# 307515                      8095.5                     8095.5
#
#         PREV_AMT_DOWN_PAYMENT_SUM  PREV_AMT_GOODS_PRICE_MEAN  \
# 307511                     2520.0                    24835.5
# 307512                     4464.0                    44617.5
# 307513                     6750.0                   174495.0
# 307514                    11250.0                    82012.5
# 307515                     8095.5                   267727.5
#
#         PREV_AMT_GOODS_PRICE_MAX  PREV_AMT_GOODS_PRICE_SUM  \
# 307511                   24835.5                   24835.5
# 307512                   44617.5                   44617.5
# 307513                  450000.0                  523485.0
# 307514                  130765.5                  246037.5
# 307515                  454500.0                  535455.0
#
#         PREV_RATE_DOWN_PAYMENT_MIN  PREV_RATE_DOWN_PAYMENT_MAX  \
# 307511                    0.104326                    0.104326
# 307512                    0.108964                    0.108964
# 307513                    0.000000                    0.134434
# 307514                    0.000000                    0.173124
# 307515                    0.087554                    0.087554
#
#         PREV_RATE_DOWN_PAYMENT_MEAN  PREV_DAYS_DECISION_MIN  \
# 307511                     0.104326                 -1740.0
# 307512                     0.108964                  -757.0
# 307513                     0.067217                 -1999.0
# 307514                     0.057708                 -1805.0
# 307515                     0.087554                  -821.0
#
#         PREV_DAYS_DECISION_MAX  PREV_DAYS_DECISION_MEAN  \
# 307511                 -1740.0                  -1740.0
# 307512                  -315.0                   -536.0
# 307513                  -222.0                   -837.5
# 307514                  -531.0                  -1124.2
# 307515                  -111.0                   -466.0
#
#         PREV_CNT_PAYMENT_MEAN  PREV_CNT_PAYMENT_SUM  \
# 307511               8.000000                   8.0
# 307512              12.000000                  12.0
# 307513              17.333333                  52.0
# 307514              11.333333                  34.0
# 307515              24.000000                  48.0
#
#         PREV_PREV_CREDIT_DIFF_MEAN  PREV_PREV_CREDIT_DIFF_MAX  \
# 307511                    1048.500                     1048.5
# 307512                    2232.000                     4464.0
# 307513                  -15262.875                     3096.0
# 307514                  -43713.000                     6435.0
# 307515                  -32823.000                   -11650.5
#
#         PREV_PREV_CREDIT_DIFF_SUM  PREV_PREV_CREDIT_APPL_RATIO_MEAN  \
# 307511                     1048.5                          0.957782
# 307512                     4464.0                          0.899950
# 307513                   -61051.5                          1.052363
# 307514                  -218565.0                               inf
# 307515                   -65646.0                          1.131358
#
#         PREV_PREV_CREDIT_APPL_RATIO_MAX  PREV_PREV_GOODS_DIFF_MEAN  \
# 307511                         0.957782                        0.0
# 307512                         0.899950                        0.0
# 307513                         1.138600                        0.0
# 307514                              inf                        0.0
# 307515                         1.143913                        0.0
#
#         PREV_PREV_GOODS_DIFF_MAX  PREV_PREV_GOODS_DIFF_SUM  \
# 307511                       0.0                       0.0
# 307512                       0.0                       0.0
# 307513                       0.0                       0.0
# 307514                       0.0                       0.0
# 307515                       0.0                       0.0
#
#         PREV_PREV_GOODS_APPL_RATIO_MEAN  PREV_PREV_GOODS_APPL_RATIO_MAX  \
# 307511                              1.0                             1.0
# 307512                              1.0                             1.0
# 307513                              1.0                             1.0
# 307514                              1.0                             1.0
# 307515                              1.0                             1.0
#
#         PREV_PREV_DAYS_LAST_DUE_DIFF_MEAN  PREV_PREV_DAYS_LAST_DUE_DIFF_MAX  \
# 307511                              120.0                             120.0
# 307512                               90.0                              90.0
# 307513                              200.0                             570.0
# 307514                               75.0                             150.0
# 307515                                0.0                               0.0
#
#         PREV_PREV_DAYS_LAST_DUE_DIFF_SUM  PREV_PREV_INTERESTS_RATE_MEAN  \
# 307511                             120.0                       0.041099
# 307512                              90.0                       0.036537
# 307513                             600.0                       0.027617
# 307514                             150.0                           -inf
# 307515                               0.0                       0.028434
#
#         PREV_PREV_INTERESTS_RATE_MAX  PREV_REFUSED_RATIO  PREV_APPROVED_RATIO  \
# 307511                      0.041099                 0.0                 1.00
# 307512                      0.036537                 0.0                 0.50
# 307513                      0.036400                 0.0                 0.75
# 307514                      0.017550                 0.0                 0.60
# 307515                      0.036536                 0.0                 0.50
#
#         PREV_CASH_LOANS_RATIO    TARGET
# 307511                    0.0  0.024785
# 307512                    0.5  0.087146
# 307513                    0.5  0.017020
# 307514                    0.2  0.044047
# 307515                    0.5  0.169549

# %% [markdown]
# ##### cross validation 으로 hyper parameter 재 tuning

# %%
bayesian_params = {
    'max_depth': (6, 16), 
    'num_leaves': (24, 64), 
    'min_data_in_leaf': (10, 200), # min_child_samples
    'min_child_weight':(1, 50),
    'bagging_fraction':(0.5, 1.0), # subsample
    'feature_fraction': (0.5, 1.0), # colsample_bytree
    'max_bin':(10, 500),
    'lambda_l2':(0.001, 10), # reg_lambda
    'lambda_l1': (0.01, 50) # reg_alpha
}

# %%
import lightgbm as lgb

train_data = lgb.Dataset(data=ftr_app, label=target_app, free_raw_data=False)
def lgb_roc_eval_cv(max_depth, num_leaves, min_data_in_leaf, min_child_weight, bagging_fraction, 
                 feature_fraction,  max_bin, lambda_l2, lambda_l1):   
    params = {
        "num_iterations":500, "learning_rate":0.02,
        'early_stopping_rounds':100, 'metric':'auc',
        'max_depth': int(round(max_depth)), #  호출 시 실수형 값이 들어오므로 실수형 하이퍼 파라미터는 정수형으로 변경 
        'num_leaves': int(round(num_leaves)), 
        'min_data_in_leaf': int(round(min_data_in_leaf)),
        'min_child_weight': int(round(min_child_weight)),
        'bagging_fraction': max(min(bagging_fraction, 1), 0), 
        'feature_fraction': max(min(feature_fraction, 1), 0),
        'max_bin':  max(int(round(max_bin)),10),
        'lambda_l2': max(lambda_l2,0),
        'lambda_l1': max(lambda_l1, 0)
    }
    # 파이썬 lightgbm의 cv 메소드를 사용. 
    
    cv_result = lgb.cv(params, train_data, nfold=3, seed=0,  verbose_eval =100,  early_stopping_rounds=50, metrics=['auc'])
    return max(cv_result['auc-mean'])

# %%
max_dict = lgbBO.res[np.argmax(np.array(target_list))]
print(max_dict)

# %%
def train_apps_all(apps_all_train):
    ftr_app = apps_all_train.drop(['SK_ID_CURR', 'TARGET'], axis=1)
    target_app = apps_all_train['TARGET']

    train_x, valid_x, train_y, valid_y = train_test_split(ftr_app, target_app, test_size=0.3, random_state=2020)
    print('train shape:', train_x.shape, 'valid shape:', valid_x.shape)
    clf = LGBMClassifier(
                nthread=4,
                n_estimators=1000,
                learning_rate=0.02,
                max_depth = 10,
                num_leaves=60,
                colsample_bytree=0.511,
                subsample=0.785,
                max_bin=208,
                reg_alpha=7.009,
                reg_lambda=6.579,
                min_child_weight=40,
                min_child_samples=91,
                silent=-1,
                verbose=-1,
                )

    clf.fit(train_x, train_y, eval_set=[(train_x, train_y), (valid_x, valid_y)], eval_metric= 'auc', verbose= 100, 
                early_stopping_rounds= 100)
    
    return clf

# %%
apps_all = get_apps_all_with_prev_agg(apps, prev)
apps_all = get_apps_all_encoded(apps_all)
apps_all_train, apps_all_test = get_apps_all_train_test(apps_all)
clf = train_apps_all(apps_all_train)

# %%
preds = clf.predict_proba(apps_all_test.drop('SK_ID_CURR', axis=1))[:, 1 ]
apps_all_test['TARGET'] = preds
# SK_ID_CURR과 TARGET 값만 csv 형태로 생성. 코랩 버전은 구글 드라이브 절대 경로로 입력  
default_dir = "/content/gdrive/My Drive"
app_test[['SK_ID_CURR', 'TARGET']].to_csv(os.path.join(default_dir,'prev_baseline_tuning_02.csv'), index=False)
